# %%
import pandas as pd
import numpy as np

# %%
wcat = pd.read_csv('wcat.csv')

# %%
import matplotlib.pyplot as plt
plt.scatter(wcat.Waist,wcat.AT,color = 'green')

# %%
np.corrcoef(wcat.Waist,wcat.AT)
# Out:
# array([[1.        , 0.81855781],
#        [0.81855781, 1.        ]])

# %%
np.cov(wcat.Waist,wcat.AT)
# Out:
# array([[ 183.84962623,  635.91000641],
#        [ 635.91000641, 3282.68983541]])

# %%
np.cov(wcat.Waist,wcat.AT)[0,1]
# Out:
# 635.9100064135235
