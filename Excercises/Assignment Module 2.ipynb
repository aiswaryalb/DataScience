# %% [markdown]
# A. Write an equation which relates   399, 543 and 12345

# %%
eq1 = 399 + 543 - 12345
eq1
# Out:
# -11403

# %% [markdown]
# “When I divide 5 with 3, I got 1. But when I divide -5 with 3, I got -2”—How would you justify it.

# %%
#performs floor division , returns quotient and for negative it returns  largest integer less than or equal to the result of regular division
print(5//3)
print(-5//3)
# Out:
# 1
# -2

# %% [markdown]
# a=5,b=3,c=10.. What will be the output of the following:
#               A. a/=b
#               B. c*=5

# %%
#a/=b is a = a/b = 5/3 =1.6666666666666667

a=5
b=3
c=10
a/=b
a
# Out:
# 1.6666666666666667

# %%
#c*=5 is c = c* 5 = 50
c*=5
c
# Out:
# 50

# %% [markdown]
# How to check the presence of an alphabet ‘s’ in word “Data Science” .

# %%
if 's' in 'Data Science':
  print("yes")
else:
  print("no")
# Out:
# no

# %% [markdown]
# How can you obtain 64 by using numbers 4 and 3 .

# %%
4 ** 3
# Out:
# 64
