# %% [markdown]
# MODULE 3 Variables
# 	•	What will be the output of the following (can/cannot):
# 	•	Age1=5
# 	•	5age=55

# %%
#This gives no error Age1=5
# This will give error as variable cannot start with number 5age=55

# %% [markdown]
# •	What will be the output of following (can/cannot):
# 	•	Age_1=100
# 	•	age@1=100

# %% [markdown]
#  This will not give any error Age_1=100
#
# This will give error as variable name cannot have special characters except underscore age@1=100

# %% [markdown]
# 	•	How can you delete variables in Python ?

# %%
#Keyword del can be used for this purpose
var1 = 100
var1
# Out:
# 100

# %%
del var1
