# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %% [markdown]
# Seed gives same random value

# %%
df = pd.DataFrame(randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
df['W']
# Out:
# A   -0.993263
# B    1.025984
# C    2.154846
# D    0.147027
# E   -0.925874
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Dataframe is a bunch of series that shares same index

# %%
df.W
#columns can be accessed like this as well but bracket notation is prefered
# Out:
# A   -0.993263
# B    1.025984
# C    2.154846
# D    0.147027
# E   -0.925874
# Name: W, dtype: float64

# %%
df[['W','Z']]
# Out:
#           W         Z
# A -0.993263  0.000366
# B  1.025984  0.649826
# C  2.154846 -0.346419
# D  0.147027  1.024810
# E -0.925874  0.610478

# %%
#creating new column
df['new'] = df['W'] + df['Y']
df
# Out:
#           W         X         Y         Z       new
# A -0.993263  0.196800 -1.136645  0.000366 -2.129908
# B  1.025984 -0.156598 -0.031579  0.649826  0.994405
# C  2.154846 -0.610259 -0.755325 -0.346419  1.399521
# D  0.147027 -0.479448  0.558769  1.024810  0.705796
# E -0.925874  1.862864 -1.133817  0.610478 -2.059691

# %%
#removing columns
# df.drop('new') will give error as the axis has to be mentioned
# axis for columns = 1
df.drop('new',axis = 1)
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.993263  0.196800 -1.136645  0.000366 -2.129908
# B  1.025984 -0.156598 -0.031579  0.649826  0.994405
# C  2.154846 -0.610259 -0.755325 -0.346419  1.399521
# D  0.147027 -0.479448  0.558769  1.024810  0.705796
# E -0.925874  1.862864 -1.133817  0.610478 -2.059691

# %%
#here the 'new' columns is not removed , 
#this is done so that data is not accidentally deleted
#To remove permenatntly do as below
df.drop('new',axis = 1,inplace=True)
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
#rows can also be dropped
df.drop('E')
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %% [markdown]
# For columns axis =1 and rows =0, df shape is a tuple (r,c) so r=0 and c=1

# %%
#Selecting rows
#Method 1 label based
df.loc['C']
# Out:
# W    2.154846
# X   -0.610259
# Y   -0.755325
# Z   -0.346419
# Name: C, dtype: float64

# %%
#Method 2 index based
df.iloc[2]
# Out:
# W    2.154846
# X   -0.610259
# Y   -0.755325
# Z   -0.346419
# Name: C, dtype: float64

# %%
#selecting subset of rows or columns
df.loc['B','Y']
# Out:
# -0.031579143908112575

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A -0.993263 -1.136645
# B  1.025984 -0.031579

# %% [markdown]
# **Conditional Selection**

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
booldf = df > 0
booldf
# Out:
#        W      X      Y      Z
# A  False   True  False   True
# B   True  False  False   True
# C   True  False  False  False
# D   True  False   True   True
# E  False   True  False   True

# %%
df[booldf]
#gives null for false, gives same result as df[df>0]
# Out:
#           W         X         Y         Z
# A       NaN  0.196800       NaN  0.000366
# B  1.025984       NaN       NaN  0.649826
# C  2.154846       NaN       NaN       NaN
# D  0.147027       NaN  0.558769  1.024810
# E       NaN  1.862864       NaN  0.610478

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A       NaN  0.196800       NaN  0.000366
# B  1.025984       NaN       NaN  0.649826
# C  2.154846       NaN       NaN       NaN
# D  0.147027       NaN  0.558769  1.024810
# E       NaN  1.862864       NaN  0.610478

# %%
df['W'] > 0
# Out:
# A    False
# B     True
# C     True
# D     True
# E    False
# Name: W, dtype: bool

# %%
df[df['W']>0]
#gives all rows where true is present
# Out:
#           W         X         Y         Z
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
df[df['Z']<0]
# Out:
#           W         X         Y         Z
# C  2.154846 -0.610259 -0.755325 -0.346419

# %%
df[df['W']>0]['X']
# Out:
# B   -0.156598
# C   -0.610259
# D   -0.479448
# Name: X, dtype: float64

# %%
df[df['W']>0][['Y','X']]
# Out:
#           Y         X
# B -0.031579 -0.156598
# C -0.755325 -0.610259
# D  0.558769 -0.479448

# %%
#returning df with W>0 and Y<1
#df[df['W']>0 and df['Y']>1] gives error
#and can only work on single instances so use &, use | for or
df[(df['W']>0) & (df['Y']<1)]
# Out:
#           W         X         Y         Z
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
#Resetting index
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A -0.993263  0.196800 -1.136645  0.000366
# 1     B  1.025984 -0.156598 -0.031579  0.649826
# 2     C  2.154846 -0.610259 -0.755325 -0.346419
# 3     D  0.147027 -0.479448  0.558769  1.024810
# 4     E -0.925874  1.862864 -1.133817  0.610478

# %%
#resetting doesnt occur inplace for that give inplace = True
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
#setting index
newind = 'CA NY WY OR CO'.split()
newind
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df['States'] = newind
df
# Out:
#           W         X         Y         Z States
# A -0.993263  0.196800 -1.136645  0.000366     CA
# B  1.025984 -0.156598 -0.031579  0.649826     NY
# C  2.154846 -0.610259 -0.755325 -0.346419     WY
# D  0.147027 -0.479448  0.558769  1.024810     OR
# E -0.925874  1.862864 -1.133817  0.610478     CO

# %%
#to set a column as index,to set permenantly add inplace = True
df.set_index('States')
# Out:
#                W         X         Y         Z
# States
# CA     -0.993263  0.196800 -1.136645  0.000366
# NY      1.025984 -0.156598 -0.031579  0.649826
# WY      2.154846 -0.610259 -0.755325 -0.346419
# OR      0.147027 -0.479448  0.558769  1.024810
# CO     -0.925874  1.862864 -1.133817  0.610478

# %%
df
# Out:
#           W         X         Y         Z States
# A -0.993263  0.196800 -1.136645  0.000366     CA
# B  1.025984 -0.156598 -0.031579  0.649826     NY
# C  2.154846 -0.610259 -0.755325 -0.346419     WY
# D  0.147027 -0.479448  0.558769  1.024810     OR
# E -0.925874  1.862864 -1.133817  0.610478     CO

# %% [markdown]
# Multi index and index hierarchy

# %%
# Index Levels
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
df1 = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['A','B'])
df1
# Out:
#              A         B
# G1 1  0.386030  2.084019
#    2 -0.376519  0.230336
#    3  0.681209  1.035125
# G2 1 -0.031160  1.939932
#    2 -1.005187 -0.741790
#    3  0.187125 -0.732845

# %%
df1.loc['G1'].loc[1]
# Out:
# A    0.386030
# B    2.084019
# Name: 1, dtype: float64

# %%
df1.index.names =['Group','Num']
df1
# Out:
#                   A         B
# Group Num
# G1    1    0.386030  2.084019
#       2   -0.376519  0.230336
#       3    0.681209  1.035125
# G2    1   -0.031160  1.939932
#       2   -1.005187 -0.741790
#       3    0.187125 -0.732845

# %%
df1.loc['G2'].loc[2]['B']
# Out:
# -0.7417897046689249

# %%
df1.loc['G1']
# Out:
#             A         B
# Num
# 1    0.386030  2.084019
# 2   -0.376519  0.230336
# 3    0.681209  1.035125

# %%
df1.xs('G1')
# Out:
#             A         B
# Num
# 1    0.386030  2.084019
# 2   -0.376519  0.230336
# 3    0.681209  1.035125

# %%
df1.xs(1,level = 'Num')
# Out:
#              A         B
# Group
# G1     0.38603  2.084019
# G2    -0.03116  1.939932
